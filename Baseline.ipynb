# %% [markdown]
# ## Question 2
#
# Using PyTorch,
# implement a version of the CNN network architecture that was discussed in class, to train and
# test a handwritten digit recognition system. You can read the paper “Backpropagation Applied to
# Handwritten Zip Code Recognition” by LeCun et al. 1989 for more details, but your architecture
# will not follow exactly what was mentioned in the paper. Use the MNIST dataset to train and test
# the system. Be sure to divide the data into a single training, validation and testing set. Note that
# you do not need to resize the inputs to size 16 ×16.
#
# The baseline system should use the following: Glorot initialization, ReLU activations, mini-batch
# gradient descent with momentum (β = 0.9), early stopping and a cross-entropy loss function. Use
# a learning rate scheduler to adjust the learning rate by 10% every 10 epochs, starting with a learn-
# ing rate of 0.05. You are encouraged to use UITS Carbonate Deep Learning cluster to
# develop your system, since they have GPUs which will improve the training process.
# Generate learning curves for the validation and training set. Discuss whether this baseline system
# overfits, underfits or reasonably fits the validation data. Test this baseline system with the testing
# data and report the accuracy and show a confusion matrix. Submit your solution to this part
# of the problem in a Jupyter notebook document named: baseline.ipynb.
#
#
# ### Baseline system

# %% [markdown]
# #### Architecture
#
# - Layers
#     - input layer - image (original / scaled)
#
#     - convolution
#
#         -            feature maps
#
#         -                kernal (#glorot initialization)
#
#         -                sliding
#
#     - pooling
#
#         -                  max pooling
#
#     - repeat until flatten
#
#     - feed forward

# %%
# imports as needed for the baseline system

import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split, Subset
from torch.utils.data import DataLoader as dl
from torch import optim
from torch.optim.lr_scheduler import StepLR
from torch.autograd import Variable
from sklearn.metrics import confusion_matrix
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import copy

# %%
# This/These cell(s) is responsible for the below mentioned part of the problem statement.

# Use the MNIST dataset to train and test the system. 
# Be sure to divide the data into a single training, validation and testing set. 
# Note that you do not need to resize the inputs to size 16 ×16.

transforms = transforms.Compose([transforms.ToTensor()])
training_data = datasets.MNIST(root = 'data', train = True, transform = transforms, download = True)
train_ind, valid_ind = random_split(training_data, [50000,10000])
train_data = Subset(training_data, train_ind.indices)
valid_data = Subset(training_data, valid_ind.indices)
test_data = datasets.MNIST(root = 'data', train = False, transform = transforms)

# %%
print(train_data, len(train_data))
print(valid_data, len(valid_data))
print(test_data, len(test_data))
# Out:
# <torch.utils.data.dataset.Subset object at 0x7fc231969a00> 50000
# <torch.utils.data.dataset.Subset object at 0x7fc2301a5310> 10000
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            ) 10000

# %%
loaders = {}
loaders['train'] =  dl(train_data, batch_size = 50, shuffle = False, num_workers=4)
loaders['valid'] = dl(valid_data, batch_size = 50, shuffle = False, num_workers=4)
loaders['test'] = dl(test_data, batch_size = 50, shuffle = False, num_workers=4)

loaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x7fc231f8f910>,
#  'valid': <torch.utils.data.dataloader.DataLoader at 0x7fc231f8fe50>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x7fc231f8f640>}

# %%
### Critical for the baseline 
### Model architecture turned to code
### Layers detailed above

### Key implementations in this cell:
### Glorot initialization as xavier_uniform
### RELU Activation
### Convolutions and Pooling

class CNN(nn.Module):
    def __init__(self):
    
        # initializing the parent object
        super(CNN, self).__init__()
        
        # creating the first convolution layer
        conv_layer1 = nn.Conv2d(1, 32, 5, 1, 2) #in-size, out-size, kernel-size, stride = 1, padding = 2              
        # initializing it as per the assignment: Glorot Initialization ~ xavier_uniform
        nn.init.xavier_uniform_(conv_layer1.weight)

        # only required to perform in a series of steps, only cursory
        self.conv1 = nn.Sequential(         
            # passing the conv layer variable created above
            conv_layer1,                      
            # relu layer, as per assignment, however, activation can be different
            nn.ReLU(),                      
            # taking the generated output from the previous convolution(s) and pooling them 
            # here, it is a max pooling, that is taking the max output from the convolution filter.
            nn.MaxPool2d(2),    
        )

        conv_layer2 = nn.Conv2d(32, 64, 5, 1, 2)
        nn.init.xavier_uniform_(conv_layer2.weight)
        self.conv2 = nn.Sequential(         
            conv_layer2,     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        
        # fully connected layer, output 10 classes
        self.dnn1 = nn.Linear(64 * 7 * 7, 32)
        self.out = nn.Linear(32, 10)
        
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        x = x.view(x.size(0), -1)  
        x = self.dnn1(x)
        output = self.out(x)
        return output, x    # return x for visualization

# %%
cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dnn1): Linear(in_features=3136, out_features=32, bias=True)
#   (out): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
# cross entropy function as mentioned in the problem statement
loss_func = nn.CrossEntropyLoss()   
loss_func
# Out:
# CrossEntropyLoss()

# %%
# as mentioned in the problem statement, 
# we are taking the SGD optimizer for performing 
# Mini Batch Gradient Descent with momentum

optimizer = optim.SGD(cnn.parameters(), lr = 0.05, momentum = 0.9)   
optimizer
scheduler = StepLR(optimizer, step_size = 10000, gamma = 0.9)
print(optimizer.param_groups[0]['lr'])
# Out:
# 0.05

# %%
# Key points from this cell:
# Early Stopping
# Training
# Validation
# Learning Rate as per epoch

num_epochs = 35
loss_tracker = []
epoch_tracker = []
valid_accuracy_tracker = []
valid_loss_tracker =[]

patience = 3
min_delta = 0
best_loss = None
counter = 0
best_model = None

def early_stopping_func(val_loss):
    global best_loss
    global patience
    global counter
    global min_delta
    #print(best_loss,val_loss,abs(best_loss - val_loss))
    if best_loss == None:
        best_loss = val_loss
    elif best_loss - val_loss > min_delta:
        best_loss = val_loss
        # reset counter if validation loss improves
        counter = 0
    elif best_loss - val_loss < min_delta:
        counter += 1
        print(f"INFO: Early stopping counter {counter} of {patience}")
        if counter >= patience:            
            print('INFO: Early stopping')
            return  True
        return False
        
        
def train(num_epochs, cnn, loaders):
    
    #early_stopping = EarlyStopping(patience=patience, verbose=True)
    global no_epochs
    cnn.train()
    # Train the model
    total_step = len(loaders['train'])
    for epoch in range(num_epochs):
        #############################
        ###### Training the model####
        #############################
        epoch_loss_tracker = []
        if epoch % 10 == 0:
            print(optimizer.param_groups[0]['lr'])
        for _, (images, labels) in enumerate(loaders['train']):
            #print(optimizer.param_groups[0]['lr'])
            # gives batch data, normalize x when iterate train_loader
            image_data = Variable(images) 
            label_data = Variable(labels) 
            output = cnn(image_data)[0]
            loss = loss_func(output, label_data)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            # backpropagation, compute gradients 
            loss.backward()    
            # apply gradients             
            optimizer.step() 
            scheduler.step()
            if (_+1) % 50 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, _ + 1, total_step, loss.item()))
            epoch_loss_tracker.append(loss)  
        loss_tracker.append(sum(epoch_loss_tracker)/1000)
        epoch_tracker.append(epoch)
        
        ##################################
        ###### Fitting on validation #####
        ##################################
        
        
        cnn.eval()
        valid_loss_batch = []
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in loaders['valid']:
            
                image_data = Variable(images) 
                label_data = Variable(labels) 
                valid_output, last_layer = cnn(images)
                loss = loss_func(valid_output, label_data)
                valid_loss_batch.append(loss)

                valid_pred_y = torch.max(valid_output, 1)[1].data.squeeze()
                accuracy = (valid_pred_y == labels).sum().item() / float(labels.size(0))
                valid_accuracy_tracker.append(accuracy)
        print('Validation Accuracy of the model on the 10000 validation images: %.2f' % accuracy)
        
        valid_loss = np.average(np.array(valid_loss_batch))
        valid_loss_tracker.append(valid_loss)
        
        print(valid_loss)
        
        global best_model 
        if early_stopping_func(valid_loss):
            print("Early stopping")
            no_epochs = epoch
            best_model = copy.deepcopy(cnn)
        
train(num_epochs, cnn, loaders)
# Out:
# 0.05
# Epoch [1/35], Step [50/1000], Loss: 0.8909
# Epoch [1/35], Step [100/1000], Loss: 0.1107
# Epoch [1/35], Step [150/1000], Loss: 0.2748
# Epoch [1/35], Step [200/1000], Loss: 0.2241
# Epoch [1/35], Step [250/1000], Loss: 0.0592
# Epoch [1/35], Step [300/1000], Loss: 0.0921
# Epoch [1/35], Step [350/1000], Loss: 0.0669
# Epoch [1/35], Step [400/1000], Loss: 0.0987
# Epoch [1/35], Step [450/1000], Loss: 0.0232
# Epoch [1/35], Step [500/1000], Loss: 0.4398
# Epoch [1/35], Step [550/1000], Loss: 0.0282
# Epoch [1/35], Step [600/1000], Loss: 0.1098
# Epoch [1/35], Step [650/1000], Loss: 0.0737
# Epoch [1/35], Step [700/1000], Loss: 0.0195
# Epoch [1/35], Step [750/1000], Loss: 0.1090
# Epoch [1/35], Step [800/1000], Loss: 0.0240
# Epoch [1/35], Step [850/1000], Loss: 0.0232
# Epoch [1/35], Step [900/1000], Loss: 0.1463
# Epoch [1/35], Step [950/1000], Loss: 0.0200
# Epoch [1/35], Step [1000/1000], Loss: 0.0027
# Validation Accuracy of the model on the 10000 validation images: 0.96
# 0.06922754
# Epoch [2/35], Step [50/1000], Loss: 0.0624
# Epoch [2/35], Step [100/1000], Loss: 0.1051
# Epoch [2/35], Step [150/1000], Loss: 0.1045
# Epoch [2/35], Step [200/1000], Loss: 0.1251
# Epoch [2/35], Step [250/1000], Loss: 0.0308
# Epoch [2/35], Step [300/1000], Loss: 0.2077
# Epoch [2/35], Step [350/1000], Loss: 0.0248
# Epoch [2/35], Step [400/1000], Loss: 0.0066
# Epoch [2/35], Step [450/1000], Loss: 0.0586
# Epoch [2/35], Step [500/1000], Loss: 0.4680
# Epoch [2/35], Step [550/1000], Loss: 0.1545
# Epoch [2/35], Step [600/1000], Loss: 0.0561
# Epoch [2/35], Step [650/1000], Loss: 0.0288
# Epoch [2/35], Step [700/1000], Loss: 0.0057
# Epoch [2/35], Step [750/1000], Loss: 0.0083
# Epoch [2/35], Step [800/1000], Loss: 0.0434
# Epoch [2/35], Step [850/1000], Loss: 0.0094
# Epoch [2/35], Step [900/1000], Loss: 0.1148
# Epoch [2/35], Step [950/1000], Loss: 0.0100
# Epoch [2/35], Step [1000/1000], Loss: 0.0011
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.046424657
# Epoch [3/35], Step [50/1000], Loss: 0.0323
# Epoch [3/35], Step [100/1000], Loss: 0.0129
# Epoch [3/35], Step [150/1000], Loss: 0.0576
# Epoch [3/35], Step [200/1000], Loss: 0.0296
# Epoch [3/35], Step [250/1000], Loss: 0.0478
# Epoch [3/35], Step [300/1000], Loss: 0.0859
# Epoch [3/35], Step [350/1000], Loss: 0.0260
# Epoch [3/35], Step [400/1000], Loss: 0.0011
# Epoch [3/35], Step [450/1000], Loss: 0.0014
# Epoch [3/35], Step [500/1000], Loss: 0.1064
# Epoch [3/35], Step [550/1000], Loss: 0.0631
# Epoch [3/35], Step [600/1000], Loss: 0.0525
# Epoch [3/35], Step [650/1000], Loss: 0.0111
# Epoch [3/35], Step [700/1000], Loss: 0.0018
# Epoch [3/35], Step [750/1000], Loss: 0.0012
# Epoch [3/35], Step [800/1000], Loss: 0.0365
# Epoch [3/35], Step [850/1000], Loss: 0.0186
# Epoch [3/35], Step [900/1000], Loss: 0.0798
# Epoch [3/35], Step [950/1000], Loss: 0.0065
# Epoch [3/35], Step [1000/1000], Loss: 0.0005
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.04202488
# Epoch [4/35], Step [50/1000], Loss: 0.0103
# Epoch [4/35], Step [100/1000], Loss: 0.0066
# Epoch [4/35], Step [150/1000], Loss: 0.1042
# Epoch [4/35], Step [200/1000], Loss: 0.1303
# Epoch [4/35], Step [250/1000], Loss: 0.0187
# Epoch [4/35], Step [300/1000], Loss: 0.0889
# Epoch [4/35], Step [350/1000], Loss: 0.0066
# Epoch [4/35], Step [400/1000], Loss: 0.0044
# Epoch [4/35], Step [450/1000], Loss: 0.0034
# Epoch [4/35], Step [500/1000], Loss: 0.0089
# Epoch [4/35], Step [550/1000], Loss: 0.0006
# Epoch [4/35], Step [600/1000], Loss: 0.0090
# Epoch [4/35], Step [650/1000], Loss: 0.0021
# Epoch [4/35], Step [700/1000], Loss: 0.0017
# Epoch [4/35], Step [750/1000], Loss: 0.0026
# Epoch [4/35], Step [800/1000], Loss: 0.0389
# Epoch [4/35], Step [850/1000], Loss: 0.0057
# Epoch [4/35], Step [900/1000], Loss: 0.0270
# Epoch [4/35], Step [950/1000], Loss: 0.0017
# Epoch [4/35], Step [1000/1000], Loss: 0.0011
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.047326826
# INFO: Early stopping counter 1 of 3
# Epoch [5/35], Step [50/1000], Loss: 0.0082
# Epoch [5/35], Step [100/1000], Loss: 0.0041
# Epoch [5/35], Step [150/1000], Loss: 0.0031
# Epoch [5/35], Step [200/1000], Loss: 0.0093
# Epoch [5/35], Step [250/1000], Loss: 0.0634
# Epoch [5/35], Step [300/1000], Loss: 0.1526
# Epoch [5/35], Step [350/1000], Loss: 0.0280
# Epoch [5/35], Step [400/1000], Loss: 0.0004
# Epoch [5/35], Step [450/1000], Loss: 0.0001
# Epoch [5/35], Step [500/1000], Loss: 0.0011
# Epoch [5/35], Step [550/1000], Loss: 0.0014
# Epoch [5/35], Step [600/1000], Loss: 0.0096
# Epoch [5/35], Step [650/1000], Loss: 0.0006
# Epoch [5/35], Step [700/1000], Loss: 0.0004
# Epoch [5/35], Step [750/1000], Loss: 0.0021
# Epoch [5/35], Step [800/1000], Loss: 0.0012
# Epoch [5/35], Step [850/1000], Loss: 0.0011
# Epoch [5/35], Step [900/1000], Loss: 0.0399
# Epoch [5/35], Step [950/1000], Loss: 0.0005
# Epoch [5/35], Step [1000/1000], Loss: 0.0095
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.049366087
# INFO: Early stopping counter 2 of 3
# Epoch [6/35], Step [50/1000], Loss: 0.0371
# Epoch [6/35], Step [100/1000], Loss: 0.0004
# Epoch [6/35], Step [150/1000], Loss: 0.2114
# Epoch [6/35], Step [200/1000], Loss: 0.0121
# Epoch [6/35], Step [250/1000], Loss: 0.0086
# Epoch [6/35], Step [300/1000], Loss: 0.0792
# Epoch [6/35], Step [350/1000], Loss: 0.0137
# Epoch [6/35], Step [400/1000], Loss: 0.0004
# Epoch [6/35], Step [450/1000], Loss: 0.0013
# Epoch [6/35], Step [500/1000], Loss: 0.0748
# Epoch [6/35], Step [550/1000], Loss: 0.0884
# Epoch [6/35], Step [600/1000], Loss: 0.0035
# Epoch [6/35], Step [650/1000], Loss: 0.0658
# Epoch [6/35], Step [700/1000], Loss: 0.0000
# Epoch [6/35], Step [750/1000], Loss: 0.0003
# Epoch [6/35], Step [800/1000], Loss: 0.0037
# Epoch [6/35], Step [850/1000], Loss: 0.0594
# Epoch [6/35], Step [900/1000], Loss: 0.0983
# Epoch [6/35], Step [950/1000], Loss: 0.0058
# Epoch [6/35], Step [1000/1000], Loss: 0.0259
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.05937817
# INFO: Early stopping counter 3 of 3
# INFO: Early stopping
# Early stopping
# Epoch [7/35], Step [50/1000], Loss: 0.0017
# Epoch [7/35], Step [100/1000], Loss: 0.0002
# Epoch [7/35], Step [150/1000], Loss: 0.0506
# Epoch [7/35], Step [200/1000], Loss: 0.0063
# Epoch [7/35], Step [250/1000], Loss: 0.0107
# Epoch [7/35], Step [300/1000], Loss: 0.0670
# Epoch [7/35], Step [350/1000], Loss: 0.0794
# Epoch [7/35], Step [400/1000], Loss: 0.0158
# Epoch [7/35], Step [450/1000], Loss: 0.0003
# Epoch [7/35], Step [500/1000], Loss: 0.1221
# Epoch [7/35], Step [550/1000], Loss: 0.0157
# Epoch [7/35], Step [600/1000], Loss: 0.0429
# Epoch [7/35], Step [650/1000], Loss: 0.0025
# Epoch [7/35], Step [700/1000], Loss: 0.0036
# Epoch [7/35], Step [750/1000], Loss: 0.0003
# Epoch [7/35], Step [800/1000], Loss: 0.0005
# Epoch [7/35], Step [850/1000], Loss: 0.0101
# Epoch [7/35], Step [900/1000], Loss: 0.1149
# Epoch [7/35], Step [950/1000], Loss: 0.0000
# Epoch [7/35], Step [1000/1000], Loss: 0.0101
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.06743918
# INFO: Early stopping counter 4 of 3
# INFO: Early stopping
# Early stopping
# Epoch [8/35], Step [50/1000], Loss: 0.0099
# Epoch [8/35], Step [100/1000], Loss: 0.0140
# Epoch [8/35], Step [150/1000], Loss: 0.0057
# Epoch [8/35], Step [200/1000], Loss: 0.0949
# Epoch [8/35], Step [250/1000], Loss: 0.0021
# Epoch [8/35], Step [300/1000], Loss: 0.0030
# Epoch [8/35], Step [350/1000], Loss: 0.0798
# Epoch [8/35], Step [400/1000], Loss: 0.0694
# Epoch [8/35], Step [450/1000], Loss: 0.0012
# Epoch [8/35], Step [500/1000], Loss: 0.4166
# Epoch [8/35], Step [550/1000], Loss: 0.0019
# Epoch [8/35], Step [600/1000], Loss: 0.0503
# Epoch [8/35], Step [650/1000], Loss: 0.0031
# Epoch [8/35], Step [700/1000], Loss: 0.0109
# Epoch [8/35], Step [750/1000], Loss: 0.0095
# Epoch [8/35], Step [800/1000], Loss: 0.0642
# Epoch [8/35], Step [850/1000], Loss: 0.0002
# Epoch [8/35], Step [900/1000], Loss: 0.0065
# Epoch [8/35], Step [950/1000], Loss: 0.0003
# Epoch [8/35], Step [1000/1000], Loss: 0.0019
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.06254022
# INFO: Early stopping counter 5 of 3
# INFO: Early stopping
# Early stopping
# Epoch [9/35], Step [50/1000], Loss: 0.0871
# Epoch [9/35], Step [100/1000], Loss: 0.0005
# Epoch [9/35], Step [150/1000], Loss: 0.2339
# Epoch [9/35], Step [200/1000], Loss: 0.0005
# Epoch [9/35], Step [250/1000], Loss: 0.0198
# Epoch [9/35], Step [300/1000], Loss: 0.0045
# Epoch [9/35], Step [350/1000], Loss: 0.0003
# Epoch [9/35], Step [400/1000], Loss: 0.0071
# Epoch [9/35], Step [450/1000], Loss: 0.0091
# Epoch [9/35], Step [500/1000], Loss: 0.0765
# Epoch [9/35], Step [550/1000], Loss: 0.0003
# Epoch [9/35], Step [600/1000], Loss: 0.0000
# Epoch [9/35], Step [650/1000], Loss: 0.0056
# Epoch [9/35], Step [700/1000], Loss: 0.0008
# Epoch [9/35], Step [750/1000], Loss: 0.0002
# Epoch [9/35], Step [800/1000], Loss: 0.0918
# Epoch [9/35], Step [850/1000], Loss: 0.0003
# Epoch [9/35], Step [900/1000], Loss: 0.1413
# Epoch [9/35], Step [950/1000], Loss: 0.0001
# Epoch [9/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.06872541
# INFO: Early stopping counter 6 of 3
# INFO: Early stopping
# Early stopping
# Epoch [10/35], Step [50/1000], Loss: 0.0009
# Epoch [10/35], Step [100/1000], Loss: 0.0389
# Epoch [10/35], Step [150/1000], Loss: 0.0002
# Epoch [10/35], Step [200/1000], Loss: 0.0021
# Epoch [10/35], Step [250/1000], Loss: 0.0925
# Epoch [10/35], Step [300/1000], Loss: 0.0020
# Epoch [10/35], Step [350/1000], Loss: 0.0015
# Epoch [10/35], Step [400/1000], Loss: 0.0523
# Epoch [10/35], Step [450/1000], Loss: 0.0005
# Epoch [10/35], Step [500/1000], Loss: 0.0068
# Epoch [10/35], Step [550/1000], Loss: 0.0004
# Epoch [10/35], Step [600/1000], Loss: 0.0027
# Epoch [10/35], Step [650/1000], Loss: 0.0001
# Epoch [10/35], Step [700/1000], Loss: 0.0009
# Epoch [10/35], Step [750/1000], Loss: 0.0001
# Epoch [10/35], Step [800/1000], Loss: 0.0004
# Epoch [10/35], Step [850/1000], Loss: 0.0000
# Epoch [10/35], Step [900/1000], Loss: 0.0017
# Epoch [10/35], Step [950/1000], Loss: 0.0000
# Epoch [10/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.08306469
# INFO: Early stopping counter 7 of 3
# INFO: Early stopping
# Early stopping
# 0.045000000000000005
# Epoch [11/35], Step [50/1000], Loss: 0.0157
# Epoch [11/35], Step [100/1000], Loss: 0.0011
# Epoch [11/35], Step [150/1000], Loss: 0.3524
# Epoch [11/35], Step [200/1000], Loss: 0.0158
# Epoch [11/35], Step [250/1000], Loss: 0.0254
# Epoch [11/35], Step [300/1000], Loss: 0.2188
# Epoch [11/35], Step [350/1000], Loss: 0.0041
# Epoch [11/35], Step [400/1000], Loss: 0.0069
# Epoch [11/35], Step [450/1000], Loss: 0.0117
# Epoch [11/35], Step [500/1000], Loss: 0.0011
# Epoch [11/35], Step [550/1000], Loss: 0.0026
# Epoch [11/35], Step [600/1000], Loss: 0.0072
# Epoch [11/35], Step [650/1000], Loss: 0.0001
# Epoch [11/35], Step [700/1000], Loss: 0.0244
# Epoch [11/35], Step [750/1000], Loss: 0.0000
# Epoch [11/35], Step [800/1000], Loss: 0.0000
# Epoch [11/35], Step [850/1000], Loss: 0.0002
# Epoch [11/35], Step [900/1000], Loss: 0.0009
# Epoch [11/35], Step [950/1000], Loss: 0.0020
# Epoch [11/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.066917814
# INFO: Early stopping counter 8 of 3
# INFO: Early stopping
# Early stopping
# Epoch [12/35], Step [50/1000], Loss: 0.0021
# Epoch [12/35], Step [100/1000], Loss: 0.0065
# Epoch [12/35], Step [150/1000], Loss: 0.0536
# Epoch [12/35], Step [200/1000], Loss: 0.0194
# Epoch [12/35], Step [250/1000], Loss: 0.0004
# Epoch [12/35], Step [300/1000], Loss: 0.0017
# Epoch [12/35], Step [350/1000], Loss: 0.0335
# Epoch [12/35], Step [400/1000], Loss: 0.0006
# Epoch [12/35], Step [450/1000], Loss: 0.0000
# Epoch [12/35], Step [500/1000], Loss: 0.0241
# Epoch [12/35], Step [550/1000], Loss: 0.0000
# Epoch [12/35], Step [600/1000], Loss: 0.0121
# Epoch [12/35], Step [650/1000], Loss: 0.0005
# Epoch [12/35], Step [700/1000], Loss: 0.0004
# Epoch [12/35], Step [750/1000], Loss: 0.0002
# Epoch [12/35], Step [800/1000], Loss: 0.0250
# Epoch [12/35], Step [850/1000], Loss: 0.0389
# Epoch [12/35], Step [900/1000], Loss: 0.0001
# Epoch [12/35], Step [950/1000], Loss: 0.0018
# Epoch [12/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.06809504
# INFO: Early stopping counter 9 of 3
# INFO: Early stopping
# Early stopping
# Epoch [13/35], Step [50/1000], Loss: 0.0051
# Epoch [13/35], Step [100/1000], Loss: 0.0000
# Epoch [13/35], Step [150/1000], Loss: 0.0140
# Epoch [13/35], Step [200/1000], Loss: 0.1029
# Epoch [13/35], Step [250/1000], Loss: 0.0038
# Epoch [13/35], Step [300/1000], Loss: 0.0815
# Epoch [13/35], Step [350/1000], Loss: 0.0044
# Epoch [13/35], Step [400/1000], Loss: 0.0001
# Epoch [13/35], Step [450/1000], Loss: 0.0014
# Epoch [13/35], Step [500/1000], Loss: 0.0029
# Epoch [13/35], Step [550/1000], Loss: 0.0004
# Epoch [13/35], Step [600/1000], Loss: 0.0018
# Epoch [13/35], Step [650/1000], Loss: 0.0001
# Epoch [13/35], Step [700/1000], Loss: 0.0000
# Epoch [13/35], Step [750/1000], Loss: 0.0002
# Epoch [13/35], Step [800/1000], Loss: 0.0010
# Epoch [13/35], Step [850/1000], Loss: 0.0527
# Epoch [13/35], Step [900/1000], Loss: 0.0071
# Epoch [13/35], Step [950/1000], Loss: 0.0000
# Epoch [13/35], Step [1000/1000], Loss: 0.0006
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.053140774
# INFO: Early stopping counter 10 of 3
# INFO: Early stopping
# Early stopping
# Epoch [14/35], Step [50/1000], Loss: 0.0035
# Epoch [14/35], Step [100/1000], Loss: 0.0578
# Epoch [14/35], Step [150/1000], Loss: 0.0211
# Epoch [14/35], Step [200/1000], Loss: 0.0094
# Epoch [14/35], Step [250/1000], Loss: 0.1198
# Epoch [14/35], Step [300/1000], Loss: 0.0003
# Epoch [14/35], Step [350/1000], Loss: 0.0000
# Epoch [14/35], Step [400/1000], Loss: 0.0001
# Epoch [14/35], Step [450/1000], Loss: 0.0005
# Epoch [14/35], Step [500/1000], Loss: 0.1205
# Epoch [14/35], Step [550/1000], Loss: 0.0001
# Epoch [14/35], Step [600/1000], Loss: 0.1233
# Epoch [14/35], Step [650/1000], Loss: 0.0004
# Epoch [14/35], Step [700/1000], Loss: 0.0000
# Epoch [14/35], Step [750/1000], Loss: 0.0000
# Epoch [14/35], Step [800/1000], Loss: 0.0000
# Epoch [14/35], Step [850/1000], Loss: 0.0002
# Epoch [14/35], Step [900/1000], Loss: 0.0535
# Epoch [14/35], Step [950/1000], Loss: 0.0021
# Epoch [14/35], Step [1000/1000], Loss: 0.0001
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.076547615
# INFO: Early stopping counter 11 of 3
# INFO: Early stopping
# Early stopping
# Epoch [15/35], Step [50/1000], Loss: 0.2845
# Epoch [15/35], Step [100/1000], Loss: 0.0000
# Epoch [15/35], Step [150/1000], Loss: 0.0001
# Epoch [15/35], Step [200/1000], Loss: 0.0016
# Epoch [15/35], Step [250/1000], Loss: 0.0170
# Epoch [15/35], Step [300/1000], Loss: 0.0003
# Epoch [15/35], Step [350/1000], Loss: 0.0008
# Epoch [15/35], Step [400/1000], Loss: 0.0001
# Epoch [15/35], Step [450/1000], Loss: 0.0108
# Epoch [15/35], Step [500/1000], Loss: 0.0330
# Epoch [15/35], Step [550/1000], Loss: 0.0046
# Epoch [15/35], Step [600/1000], Loss: 0.0175
# Epoch [15/35], Step [650/1000], Loss: 0.0000
# Epoch [15/35], Step [700/1000], Loss: 0.0000
# Epoch [15/35], Step [750/1000], Loss: 0.0001
# Epoch [15/35], Step [800/1000], Loss: 0.0002
# Epoch [15/35], Step [850/1000], Loss: 0.0001
# Epoch [15/35], Step [900/1000], Loss: 0.1738
# Epoch [15/35], Step [950/1000], Loss: 0.0000
# Epoch [15/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.084948465
# INFO: Early stopping counter 12 of 3
# INFO: Early stopping
# Early stopping
# Epoch [16/35], Step [50/1000], Loss: 0.0008
# Epoch [16/35], Step [100/1000], Loss: 0.0001
# Epoch [16/35], Step [150/1000], Loss: 0.0200
# Epoch [16/35], Step [200/1000], Loss: 0.1318
# Epoch [16/35], Step [250/1000], Loss: 0.0367
# Epoch [16/35], Step [300/1000], Loss: 0.0044
# Epoch [16/35], Step [350/1000], Loss: 0.0000
# Epoch [16/35], Step [400/1000], Loss: 0.0001
# Epoch [16/35], Step [450/1000], Loss: 0.0003
# Epoch [16/35], Step [500/1000], Loss: 0.0042
# Epoch [16/35], Step [550/1000], Loss: 0.3658
# Epoch [16/35], Step [600/1000], Loss: 0.1987
# Epoch [16/35], Step [650/1000], Loss: 0.0007
# Epoch [16/35], Step [700/1000], Loss: 0.0317
# Epoch [16/35], Step [750/1000], Loss: 0.0003
# Epoch [16/35], Step [800/1000], Loss: 0.1202
# Epoch [16/35], Step [850/1000], Loss: 0.0001
# Epoch [16/35], Step [900/1000], Loss: 0.0000
# Epoch [16/35], Step [950/1000], Loss: 0.0005
# Epoch [16/35], Step [1000/1000], Loss: 0.0440
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.07943628
# INFO: Early stopping counter 13 of 3
# INFO: Early stopping
# Early stopping
# Epoch [17/35], Step [50/1000], Loss: 0.0000
# Epoch [17/35], Step [100/1000], Loss: 0.0002
# Epoch [17/35], Step [150/1000], Loss: 0.0000
# Epoch [17/35], Step [200/1000], Loss: 0.0124
# Epoch [17/35], Step [250/1000], Loss: 0.0740
# Epoch [17/35], Step [300/1000], Loss: 0.3765
# Epoch [17/35], Step [350/1000], Loss: 0.0011
# Epoch [17/35], Step [400/1000], Loss: 0.0000
# Epoch [17/35], Step [450/1000], Loss: 0.3269
# Epoch [17/35], Step [500/1000], Loss: 0.0000
# Epoch [17/35], Step [550/1000], Loss: 0.0000
# Epoch [17/35], Step [600/1000], Loss: 0.0437
# Epoch [17/35], Step [650/1000], Loss: 0.0451
# Epoch [17/35], Step [700/1000], Loss: 0.0000
# Epoch [17/35], Step [750/1000], Loss: 0.0077
# Epoch [17/35], Step [800/1000], Loss: 0.0035
# Epoch [17/35], Step [850/1000], Loss: 0.0000
# Epoch [17/35], Step [900/1000], Loss: 0.0008
# Epoch [17/35], Step [950/1000], Loss: 0.0053
# Epoch [17/35], Step [1000/1000], Loss: 0.0001
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.07741147
# INFO: Early stopping counter 14 of 3
# INFO: Early stopping
# Early stopping
# Epoch [18/35], Step [50/1000], Loss: 0.0003
# Epoch [18/35], Step [100/1000], Loss: 0.0116
# Epoch [18/35], Step [150/1000], Loss: 0.0623
# Epoch [18/35], Step [200/1000], Loss: 0.0199
# Epoch [18/35], Step [250/1000], Loss: 0.0069
# Epoch [18/35], Step [300/1000], Loss: 0.0001
# Epoch [18/35], Step [350/1000], Loss: 0.0012
# Epoch [18/35], Step [400/1000], Loss: 0.0002
# Epoch [18/35], Step [450/1000], Loss: 0.0007
# Epoch [18/35], Step [500/1000], Loss: 0.2038
# Epoch [18/35], Step [550/1000], Loss: 0.0120
# Epoch [18/35], Step [600/1000], Loss: 0.0005
# Epoch [18/35], Step [650/1000], Loss: 0.0477
# Epoch [18/35], Step [700/1000], Loss: 0.0000
# Epoch [18/35], Step [750/1000], Loss: 0.0001
# Epoch [18/35], Step [800/1000], Loss: 0.1950
# Epoch [18/35], Step [850/1000], Loss: 0.0000
# Epoch [18/35], Step [900/1000], Loss: 0.0002
# Epoch [18/35], Step [950/1000], Loss: 0.0557
# Epoch [18/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.96
# 0.121682875
# INFO: Early stopping counter 15 of 3
# INFO: Early stopping
# Early stopping
# Epoch [19/35], Step [50/1000], Loss: 0.1268
# Epoch [19/35], Step [100/1000], Loss: 0.0000
# Epoch [19/35], Step [150/1000], Loss: 0.1286
# Epoch [19/35], Step [200/1000], Loss: 0.1541
# Epoch [19/35], Step [250/1000], Loss: 0.0998
# Epoch [19/35], Step [300/1000], Loss: 0.0009
# Epoch [19/35], Step [350/1000], Loss: 0.0037
# Epoch [19/35], Step [400/1000], Loss: 0.0069
# Epoch [19/35], Step [450/1000], Loss: 0.0001
# Epoch [19/35], Step [500/1000], Loss: 0.0952
# Epoch [19/35], Step [550/1000], Loss: 0.0001
# Epoch [19/35], Step [600/1000], Loss: 0.0266
# Epoch [19/35], Step [650/1000], Loss: 0.0000
# Epoch [19/35], Step [700/1000], Loss: 0.0325
# Epoch [19/35], Step [750/1000], Loss: 0.0000
# Epoch [19/35], Step [800/1000], Loss: 0.0002
# Epoch [19/35], Step [850/1000], Loss: 0.0000
# Epoch [19/35], Step [900/1000], Loss: 0.0004
# Epoch [19/35], Step [950/1000], Loss: 0.0000
# Epoch [19/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.08794487
# INFO: Early stopping counter 16 of 3
# INFO: Early stopping
# Early stopping
# Epoch [20/35], Step [50/1000], Loss: 0.0222
# Epoch [20/35], Step [100/1000], Loss: 0.0000
# Epoch [20/35], Step [150/1000], Loss: 0.0001
# Epoch [20/35], Step [200/1000], Loss: 0.0977
# Epoch [20/35], Step [250/1000], Loss: 0.1851
# Epoch [20/35], Step [300/1000], Loss: 0.0916
# Epoch [20/35], Step [350/1000], Loss: 0.0018
# Epoch [20/35], Step [400/1000], Loss: 0.0000
# Epoch [20/35], Step [450/1000], Loss: 0.0001
# Epoch [20/35], Step [500/1000], Loss: 0.0015
# Epoch [20/35], Step [550/1000], Loss: 0.0004
# Epoch [20/35], Step [600/1000], Loss: 0.0249
# Epoch [20/35], Step [650/1000], Loss: 0.0000
# Epoch [20/35], Step [700/1000], Loss: 0.0001
# Epoch [20/35], Step [750/1000], Loss: 0.0000
# Epoch [20/35], Step [800/1000], Loss: 0.0000
# Epoch [20/35], Step [850/1000], Loss: 0.0182
# Epoch [20/35], Step [900/1000], Loss: 0.2041
# Epoch [20/35], Step [950/1000], Loss: 0.0020
# Epoch [20/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.14306675
# INFO: Early stopping counter 17 of 3
# INFO: Early stopping
# Early stopping
# 0.04050000000000001
# Epoch [21/35], Step [50/1000], Loss: 0.2282
# Epoch [21/35], Step [100/1000], Loss: 0.0001
# Epoch [21/35], Step [150/1000], Loss: 0.2142
# Epoch [21/35], Step [200/1000], Loss: 0.1367
# Epoch [21/35], Step [250/1000], Loss: 0.0000
# Epoch [21/35], Step [300/1000], Loss: 0.0056
# Epoch [21/35], Step [350/1000], Loss: 0.0000
# Epoch [21/35], Step [400/1000], Loss: 0.0000
# Epoch [21/35], Step [450/1000], Loss: 0.0000
# Epoch [21/35], Step [500/1000], Loss: 0.0192
# Epoch [21/35], Step [550/1000], Loss: 0.0000
# Epoch [21/35], Step [600/1000], Loss: 0.0000
# Epoch [21/35], Step [650/1000], Loss: 0.0005
# Epoch [21/35], Step [700/1000], Loss: 0.0000
# Epoch [21/35], Step [750/1000], Loss: 0.0000
# Epoch [21/35], Step [800/1000], Loss: 0.0628
# Epoch [21/35], Step [850/1000], Loss: 0.1307
# Epoch [21/35], Step [900/1000], Loss: 0.4501
# Epoch [21/35], Step [950/1000], Loss: 0.0000
# Epoch [21/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.106658496
# INFO: Early stopping counter 18 of 3
# INFO: Early stopping
# Early stopping
# Epoch [22/35], Step [50/1000], Loss: 0.0000
# Epoch [22/35], Step [100/1000], Loss: 0.0002
# Epoch [22/35], Step [150/1000], Loss: 0.0000
# Epoch [22/35], Step [200/1000], Loss: 0.0461
# Epoch [22/35], Step [250/1000], Loss: 0.0061
# Epoch [22/35], Step [300/1000], Loss: 0.1350
# Epoch [22/35], Step [350/1000], Loss: 0.0002
# Epoch [22/35], Step [400/1000], Loss: 0.0000
# Epoch [22/35], Step [450/1000], Loss: 0.0000
# Epoch [22/35], Step [500/1000], Loss: 0.0000
# Epoch [22/35], Step [550/1000], Loss: 0.0003
# Epoch [22/35], Step [600/1000], Loss: 0.0306
# Epoch [22/35], Step [650/1000], Loss: 0.0399
# Epoch [22/35], Step [700/1000], Loss: 0.0000
# Epoch [22/35], Step [750/1000], Loss: 0.0000
# Epoch [22/35], Step [800/1000], Loss: 0.0076
# Epoch [22/35], Step [850/1000], Loss: 0.0000
# Epoch [22/35], Step [900/1000], Loss: 0.0000
# Epoch [22/35], Step [950/1000], Loss: 0.1706
# Epoch [22/35], Step [1000/1000], Loss: 0.0429
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.1052457
# INFO: Early stopping counter 19 of 3
# INFO: Early stopping
# Early stopping
# Epoch [23/35], Step [50/1000], Loss: 0.1599
# Epoch [23/35], Step [100/1000], Loss: 0.0000
# Epoch [23/35], Step [150/1000], Loss: 0.0001
# Epoch [23/35], Step [200/1000], Loss: 0.0196
# Epoch [23/35], Step [250/1000], Loss: 0.0000
# Epoch [23/35], Step [300/1000], Loss: 0.0539
# Epoch [23/35], Step [350/1000], Loss: 0.0000
# Epoch [23/35], Step [400/1000], Loss: 0.0003
# Epoch [23/35], Step [450/1000], Loss: 0.0000
# Epoch [23/35], Step [500/1000], Loss: 0.0000
# Epoch [23/35], Step [550/1000], Loss: 0.0005
# Epoch [23/35], Step [600/1000], Loss: 0.0000
# Epoch [23/35], Step [650/1000], Loss: 0.0000
# Epoch [23/35], Step [700/1000], Loss: 0.0000
# Epoch [23/35], Step [750/1000], Loss: 0.0000
# Epoch [23/35], Step [800/1000], Loss: 0.1039
# Epoch [23/35], Step [850/1000], Loss: 0.1789
# Epoch [23/35], Step [900/1000], Loss: 0.0000
# Epoch [23/35], Step [950/1000], Loss: 0.0000
# Epoch [23/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.12951565
# INFO: Early stopping counter 20 of 3
# INFO: Early stopping
# Early stopping
# Epoch [24/35], Step [50/1000], Loss: 0.0017
# Epoch [24/35], Step [100/1000], Loss: 0.0000
# Epoch [24/35], Step [150/1000], Loss: 0.0016
# Epoch [24/35], Step [200/1000], Loss: 0.0000
# Epoch [24/35], Step [250/1000], Loss: 0.0000
# Epoch [24/35], Step [300/1000], Loss: 0.0001
# Epoch [24/35], Step [350/1000], Loss: 0.0463
# Epoch [24/35], Step [400/1000], Loss: 0.0066
# Epoch [24/35], Step [450/1000], Loss: 0.0000
# Epoch [24/35], Step [500/1000], Loss: 0.0000
# Epoch [24/35], Step [550/1000], Loss: 0.0427
# Epoch [24/35], Step [600/1000], Loss: 0.0184
# Epoch [24/35], Step [650/1000], Loss: 0.0143
# Epoch [24/35], Step [700/1000], Loss: 0.0000
# Epoch [24/35], Step [750/1000], Loss: 0.0001
# Epoch [24/35], Step [800/1000], Loss: 0.0000
# Epoch [24/35], Step [850/1000], Loss: 0.0000
# Epoch [24/35], Step [900/1000], Loss: 0.0037
# Epoch [24/35], Step [950/1000], Loss: 0.0000
# Epoch [24/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.1269668
# INFO: Early stopping counter 21 of 3
# INFO: Early stopping
# Early stopping
# Epoch [25/35], Step [50/1000], Loss: 0.0003
# Epoch [25/35], Step [100/1000], Loss: 0.0000
# Epoch [25/35], Step [150/1000], Loss: 0.2689
# Epoch [25/35], Step [200/1000], Loss: 0.0035
# Epoch [25/35], Step [250/1000], Loss: 0.0010
# Epoch [25/35], Step [300/1000], Loss: 0.0000
# Epoch [25/35], Step [350/1000], Loss: 0.0006
# Epoch [25/35], Step [400/1000], Loss: 0.0000
# Epoch [25/35], Step [450/1000], Loss: 0.0000
# Epoch [25/35], Step [500/1000], Loss: 0.1347
# Epoch [25/35], Step [550/1000], Loss: 0.0000
# Epoch [25/35], Step [600/1000], Loss: 0.1619
# Epoch [25/35], Step [650/1000], Loss: 0.0000
# Epoch [25/35], Step [700/1000], Loss: 0.0000
# Epoch [25/35], Step [750/1000], Loss: 0.0000
# Epoch [25/35], Step [800/1000], Loss: 0.0000
# Epoch [25/35], Step [850/1000], Loss: 0.0000
# Epoch [25/35], Step [900/1000], Loss: 0.0738
# Epoch [25/35], Step [950/1000], Loss: 0.0000
# Epoch [25/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.15065627
# INFO: Early stopping counter 22 of 3
# INFO: Early stopping
# Early stopping
# Epoch [26/35], Step [50/1000], Loss: 0.0010
# Epoch [26/35], Step [100/1000], Loss: 0.0816
# Epoch [26/35], Step [150/1000], Loss: 0.0002
# Epoch [26/35], Step [200/1000], Loss: 0.0000
# Epoch [26/35], Step [250/1000], Loss: 0.0717
# Epoch [26/35], Step [300/1000], Loss: 0.0374
# Epoch [26/35], Step [350/1000], Loss: 0.0000
# Epoch [26/35], Step [400/1000], Loss: 0.0273
# Epoch [26/35], Step [450/1000], Loss: 0.0033
# Epoch [26/35], Step [500/1000], Loss: 0.0003
# Epoch [26/35], Step [550/1000], Loss: 0.0006
# Epoch [26/35], Step [600/1000], Loss: 0.0227
# Epoch [26/35], Step [650/1000], Loss: 0.0001
# Epoch [26/35], Step [700/1000], Loss: 0.0000
# Epoch [26/35], Step [750/1000], Loss: 0.0000
# Epoch [26/35], Step [800/1000], Loss: 0.0359
# Epoch [26/35], Step [850/1000], Loss: 0.0000
# Epoch [26/35], Step [900/1000], Loss: 0.0000
# Epoch [26/35], Step [950/1000], Loss: 0.0000
# Epoch [26/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.16233732
# INFO: Early stopping counter 23 of 3
# INFO: Early stopping
# Early stopping
# Epoch [27/35], Step [50/1000], Loss: 0.0001
# Epoch [27/35], Step [100/1000], Loss: 0.0000
# Epoch [27/35], Step [150/1000], Loss: 0.2943
# Epoch [27/35], Step [200/1000], Loss: 0.0119
# Epoch [27/35], Step [250/1000], Loss: 0.2208
# Epoch [27/35], Step [300/1000], Loss: 0.0468
# Epoch [27/35], Step [350/1000], Loss: 0.0057
# Epoch [27/35], Step [400/1000], Loss: 0.1774
# Epoch [27/35], Step [450/1000], Loss: 0.0000
# Epoch [27/35], Step [500/1000], Loss: 0.0031
# Epoch [27/35], Step [550/1000], Loss: 0.0010
# Epoch [27/35], Step [600/1000], Loss: 0.4232
# Epoch [27/35], Step [650/1000], Loss: 0.1161
# Epoch [27/35], Step [700/1000], Loss: 0.0000
# Epoch [27/35], Step [750/1000], Loss: 0.0002
# Epoch [27/35], Step [800/1000], Loss: 0.0000
# Epoch [27/35], Step [850/1000], Loss: 0.0000
# Epoch [27/35], Step [900/1000], Loss: 0.1755
# Epoch [27/35], Step [950/1000], Loss: 0.0003
# Epoch [27/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.16103111
# INFO: Early stopping counter 24 of 3
# INFO: Early stopping
# Early stopping
# Epoch [28/35], Step [50/1000], Loss: 0.2010
# Epoch [28/35], Step [100/1000], Loss: 0.1536
# Epoch [28/35], Step [150/1000], Loss: 0.0324
# Epoch [28/35], Step [200/1000], Loss: 0.3559
# Epoch [28/35], Step [250/1000], Loss: 0.0000
# Epoch [28/35], Step [300/1000], Loss: 0.0002
# Epoch [28/35], Step [350/1000], Loss: 0.0028
# Epoch [28/35], Step [400/1000], Loss: 0.0000
# Epoch [28/35], Step [450/1000], Loss: 0.0005
# Epoch [28/35], Step [500/1000], Loss: 0.0016
# Epoch [28/35], Step [550/1000], Loss: 0.5243
# Epoch [28/35], Step [600/1000], Loss: 0.0436
# Epoch [28/35], Step [650/1000], Loss: 0.0494
# Epoch [28/35], Step [700/1000], Loss: 0.0086
# Epoch [28/35], Step [750/1000], Loss: 0.0000
# Epoch [28/35], Step [800/1000], Loss: 0.0020
# Epoch [28/35], Step [850/1000], Loss: 0.3448
# Epoch [28/35], Step [900/1000], Loss: 0.0015
# Epoch [28/35], Step [950/1000], Loss: 0.0000
# Epoch [28/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.17857598
# INFO: Early stopping counter 25 of 3
# INFO: Early stopping
# Early stopping
# Epoch [29/35], Step [50/1000], Loss: 0.0091
# Epoch [29/35], Step [100/1000], Loss: 0.0001
# Epoch [29/35], Step [150/1000], Loss: 0.1128
# Epoch [29/35], Step [200/1000], Loss: 0.0093
# Epoch [29/35], Step [250/1000], Loss: 0.0000
# Epoch [29/35], Step [300/1000], Loss: 0.0000
# Epoch [29/35], Step [350/1000], Loss: 0.1030
# Epoch [29/35], Step [400/1000], Loss: 0.0000
# Epoch [29/35], Step [450/1000], Loss: 0.0000
# Epoch [29/35], Step [500/1000], Loss: 0.8976
# Epoch [29/35], Step [550/1000], Loss: 0.0006
# Epoch [29/35], Step [600/1000], Loss: 0.3171
# Epoch [29/35], Step [650/1000], Loss: 0.0000
# Epoch [29/35], Step [700/1000], Loss: 0.0163
# Epoch [29/35], Step [750/1000], Loss: 0.0000
# Epoch [29/35], Step [800/1000], Loss: 0.0520
# Epoch [29/35], Step [850/1000], Loss: 0.0000
# Epoch [29/35], Step [900/1000], Loss: 0.0191
# Epoch [29/35], Step [950/1000], Loss: 0.0304
# Epoch [29/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.23528439
# INFO: Early stopping counter 26 of 3
# INFO: Early stopping
# Early stopping
# Epoch [30/35], Step [50/1000], Loss: 0.1894
# Epoch [30/35], Step [100/1000], Loss: 0.0256
# Epoch [30/35], Step [150/1000], Loss: 0.1696
# Epoch [30/35], Step [200/1000], Loss: 0.0790
# Epoch [30/35], Step [250/1000], Loss: 0.0000
# Epoch [30/35], Step [300/1000], Loss: 0.0002
# Epoch [30/35], Step [350/1000], Loss: 0.0024
# Epoch [30/35], Step [400/1000], Loss: 0.0000
# Epoch [30/35], Step [450/1000], Loss: 0.0011
# Epoch [30/35], Step [500/1000], Loss: 0.0451
# Epoch [30/35], Step [550/1000], Loss: 0.0000
# Epoch [30/35], Step [600/1000], Loss: 0.0088
# Epoch [30/35], Step [650/1000], Loss: 0.0894
# Epoch [30/35], Step [700/1000], Loss: 0.0012
# Epoch [30/35], Step [750/1000], Loss: 0.0007
# Epoch [30/35], Step [800/1000], Loss: 0.0056
# Epoch [30/35], Step [850/1000], Loss: 0.0070
# Epoch [30/35], Step [900/1000], Loss: 0.0000
# Epoch [30/35], Step [950/1000], Loss: 0.0071
# Epoch [30/35], Step [1000/1000], Loss: 0.0001
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.17706771
# INFO: Early stopping counter 27 of 3
# INFO: Early stopping
# Early stopping
# 0.03645000000000001
# Epoch [31/35], Step [50/1000], Loss: 0.0828
# Epoch [31/35], Step [100/1000], Loss: 0.0000
# Epoch [31/35], Step [150/1000], Loss: 0.1827
# Epoch [31/35], Step [200/1000], Loss: 0.0602
# Epoch [31/35], Step [250/1000], Loss: 0.0000
# Epoch [31/35], Step [300/1000], Loss: 0.0115
# Epoch [31/35], Step [350/1000], Loss: 0.0000
# Epoch [31/35], Step [400/1000], Loss: 0.0633
# Epoch [31/35], Step [450/1000], Loss: 0.0000
# Epoch [31/35], Step [500/1000], Loss: 0.0000
# Epoch [31/35], Step [550/1000], Loss: 0.0000
# Epoch [31/35], Step [600/1000], Loss: 0.0000
# Epoch [31/35], Step [650/1000], Loss: 0.0000
# Epoch [31/35], Step [700/1000], Loss: 0.0000
# Epoch [31/35], Step [750/1000], Loss: 0.0000
# Epoch [31/35], Step [800/1000], Loss: 0.0000
# Epoch [31/35], Step [850/1000], Loss: 0.0017
# Epoch [31/35], Step [900/1000], Loss: 0.5657
# Epoch [31/35], Step [950/1000], Loss: 0.0000
# Epoch [31/35], Step [1000/1000], Loss: 0.0158
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.12415941
# INFO: Early stopping counter 28 of 3
# INFO: Early stopping
# Early stopping
# Epoch [32/35], Step [50/1000], Loss: 0.0000
# Epoch [32/35], Step [100/1000], Loss: 0.0000
# Epoch [32/35], Step [150/1000], Loss: 0.1281
# Epoch [32/35], Step [200/1000], Loss: 0.0000
# Epoch [32/35], Step [250/1000], Loss: 0.0000
# Epoch [32/35], Step [300/1000], Loss: 0.2668
# Epoch [32/35], Step [350/1000], Loss: 0.0000
# Epoch [32/35], Step [400/1000], Loss: 0.0000
# Epoch [32/35], Step [450/1000], Loss: 0.0000
# Epoch [32/35], Step [500/1000], Loss: 0.6135
# Epoch [32/35], Step [550/1000], Loss: 0.0000
# Epoch [32/35], Step [600/1000], Loss: 0.0003
# Epoch [32/35], Step [650/1000], Loss: 0.0000
# Epoch [32/35], Step [700/1000], Loss: 0.0000
# Epoch [32/35], Step [750/1000], Loss: 0.0000
# Epoch [32/35], Step [800/1000], Loss: 0.0119
# Epoch [32/35], Step [850/1000], Loss: 0.0008
# Epoch [32/35], Step [900/1000], Loss: 0.0000
# Epoch [32/35], Step [950/1000], Loss: 0.0022
# Epoch [32/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 0.98
# 0.15810306
# INFO: Early stopping counter 29 of 3
# INFO: Early stopping
# Early stopping
# Epoch [33/35], Step [50/1000], Loss: 0.0000
# Epoch [33/35], Step [100/1000], Loss: 0.0000
# Epoch [33/35], Step [150/1000], Loss: 0.0000
# Epoch [33/35], Step [200/1000], Loss: 0.0000
# Epoch [33/35], Step [250/1000], Loss: 0.0293
# Epoch [33/35], Step [300/1000], Loss: 0.0999
# Epoch [33/35], Step [350/1000], Loss: 0.2241
# Epoch [33/35], Step [400/1000], Loss: 0.0148
# Epoch [33/35], Step [450/1000], Loss: 0.0000
# Epoch [33/35], Step [500/1000], Loss: 0.0000
# Epoch [33/35], Step [550/1000], Loss: 0.0000
# Epoch [33/35], Step [600/1000], Loss: 0.0004
# Epoch [33/35], Step [650/1000], Loss: 0.0078
# Epoch [33/35], Step [700/1000], Loss: 0.0000
# Epoch [33/35], Step [750/1000], Loss: 0.0000
# Epoch [33/35], Step [800/1000], Loss: 0.0029
# Epoch [33/35], Step [850/1000], Loss: 0.0005
# Epoch [33/35], Step [900/1000], Loss: 0.0000
# Epoch [33/35], Step [950/1000], Loss: 0.0000
# Epoch [33/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.21287945
# INFO: Early stopping counter 30 of 3
# INFO: Early stopping
# Early stopping
# Epoch [34/35], Step [50/1000], Loss: 0.0000
# Epoch [34/35], Step [100/1000], Loss: 0.0000
# Epoch [34/35], Step [150/1000], Loss: 0.3387
# Epoch [34/35], Step [200/1000], Loss: 0.0087
# Epoch [34/35], Step [250/1000], Loss: 0.0000
# Epoch [34/35], Step [300/1000], Loss: 0.0000
# Epoch [34/35], Step [350/1000], Loss: 0.0001
# Epoch [34/35], Step [400/1000], Loss: 0.0000
# Epoch [34/35], Step [450/1000], Loss: 0.0000
# Epoch [34/35], Step [500/1000], Loss: 0.0000
# Epoch [34/35], Step [550/1000], Loss: 0.0006
# Epoch [34/35], Step [600/1000], Loss: 0.0001
# Epoch [34/35], Step [650/1000], Loss: 0.4186
# Epoch [34/35], Step [700/1000], Loss: 0.0000
# Epoch [34/35], Step [750/1000], Loss: 0.1839
# Epoch [34/35], Step [800/1000], Loss: 0.0060
# Epoch [34/35], Step [850/1000], Loss: 0.0124
# Epoch [34/35], Step [900/1000], Loss: 0.0011
# Epoch [34/35], Step [950/1000], Loss: 0.0005
# Epoch [34/35], Step [1000/1000], Loss: 0.0616
# Validation Accuracy of the model on the 10000 validation images: 0.96
# 0.3590596
# INFO: Early stopping counter 31 of 3
# INFO: Early stopping
# Early stopping
# Epoch [35/35], Step [50/1000], Loss: 0.0000
# Epoch [35/35], Step [100/1000], Loss: 0.1710
# Epoch [35/35], Step [150/1000], Loss: 0.3158
# Epoch [35/35], Step [200/1000], Loss: 0.0244
# Epoch [35/35], Step [250/1000], Loss: 0.0000
# Epoch [35/35], Step [300/1000], Loss: 0.1607
# Epoch [35/35], Step [350/1000], Loss: 0.0264
# Epoch [35/35], Step [400/1000], Loss: 0.0000
# Epoch [35/35], Step [450/1000], Loss: 0.0000
# Epoch [35/35], Step [500/1000], Loss: 0.0279
# Epoch [35/35], Step [550/1000], Loss: 0.0034
# Epoch [35/35], Step [600/1000], Loss: 0.2589
# Epoch [35/35], Step [650/1000], Loss: 0.1040
# Epoch [35/35], Step [700/1000], Loss: 0.0006
# Epoch [35/35], Step [750/1000], Loss: 0.0012
# Epoch [35/35], Step [800/1000], Loss: 0.0000
# Epoch [35/35], Step [850/1000], Loss: 0.0000
# Epoch [35/35], Step [900/1000], Loss: 0.0000
# Epoch [35/35], Step [950/1000], Loss: 0.1499
# Epoch [35/35], Step [1000/1000], Loss: 0.0000
# Validation Accuracy of the model on the 10000 validation images: 1.00
# 0.26193395
# INFO: Early stopping counter 32 of 3
# INFO: Early stopping
# Early stopping

# %%
# Learning curves

# Loss vs Epoch
# for validation and training

loss = [i.data.item() for i in loss_tracker]
valid_loss = [i for i in valid_loss_tracker]
plt.title("Learning curve for Training data")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.plot(np.arange(0,num_epochs),np.array(loss), label = "Training Loss")
plt.plot(np.arange(0,num_epochs),np.array(valid_loss), label = "Validation Loss")

# %%
if best_model != None:
    cnn = copy.deepcopy(best_model)

# %%
# Training Accuracy
# Added as a part of reconcilation and validation of the model

training_accuracy_tracker = []

def test_on_training():
    # Test the validation model
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in loaders['train']:
            image_data = Variable(images) 
            label_data = Variable(labels) 
            training_output, last_layer = cnn(images)
            
            training_pred_y = torch.max(training_output, 1)[1].data.squeeze()
            accuracy = (training_pred_y == labels).sum().item() / float(labels.size(0))
            training_accuracy_tracker.append(accuracy)
    print('Training Accuracy of the model on the 50000 validation images: %.2f' % accuracy)
test_on_training()
# Out:
# Training Accuracy of the model on the 50000 validation images: 1.00

# %%
# Plotting Training Accuracy
# Added as a part of reconcilation and validation of the model


plt.title("Learning curve for Training data")
plt.xlabel("data")
plt.ylabel("accuracy")
plt.plot(np.arange(0,len(loaders['train'])),np.array(training_accuracy_tracker))

# %%
# Validation Accuracy
# Added as a part of reconcilation and validation of the model

valid_accuracy_tracker = []
valid_loss_tracker =[]


def valid():
    # Test the validation model
    cnn.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in loaders['valid']:
            image_data = Variable(images) 
            label_data = Variable(labels) 
            valid_output, last_layer = cnn(images)
            loss = loss_func(valid_output, label_data)
            valid_loss_tracker.append(loss)
            
            valid_pred_y = torch.max(valid_output, 1)[1].data.squeeze()
            accuracy = (valid_pred_y == labels).sum().item() / float(labels.size(0))
            valid_accuracy_tracker.append(accuracy)
    print('Validation Accuracy of the model on the 10000 validation images: %.2f' % accuracy)
valid()
# Out:
# Validation Accuracy of the model on the 10000 validation images: 1.00

# %%
# Plotting Validation Accuracy
# Added as a part of reconcilation and validation of the model

plt.title("Learning curve for Validation data")
plt.xlabel("data")
plt.ylabel("accuracy")
plt.plot(np.arange(0,len(loaders['valid'])),np.array(valid_accuracy_tracker))

# %%
# Testing Accuracy
# Added as a part of reconcilation and validation of the model


test_labels = []
test_pred = []
test_accuracy_tracker = []
def test():
    # Test the model
    cnn.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in loaders['test']:
            #print(labels)
            test_labels.append(labels)
            test_output, last_layer = cnn(images)
            pred_y = torch.max(test_output, 1)[1].data.squeeze()
            test_pred.append(pred_y)
            accuracy = (pred_y == labels).sum().item() / float(labels.size(0))
            test_accuracy_tracker.append(accuracy)
    print('Test Accuracy of the model on the 10000 test images: %.2f' % accuracy)

test()

test_actual = []
[test_actual.extend(i.tolist()) for i in test_labels]

test_pred_orig = []

[test_pred_orig.extend(i.tolist()) for i in test_pred]

print(len(test_pred_orig),len(test_actual))
# Out:
# Test Accuracy of the model on the 10000 test images: 1.00
# 10000 10000

# %%
# Testing Accuracy
# Added as a part of reconcilation and validation of the model


plt.title("Learning curve for Testing data")
plt.xlabel("data")
plt.ylabel("accuracy")
plt.plot(np.arange(0,len(loaders['test'])),np.array(test_accuracy_tracker))

# %%
# creating confusion matrix as mentioned in the problem statement

cm = confusion_matrix(test_pred_orig,test_actual)
print(cm)
#producing a scaled version of the confusion matrix
df_cm = pd.DataFrame(cm/np.sum(cm) * 10, index = [i for i in range(10)],
                     columns = [i for i in range(10)])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.savefig('output.png')
# Out:
# [[ 969    0    2    1    0    1    4    0    2    2]
#  [   1 1122    0    0    0    0    2    3    2    0]
#  [   0    0 1006    1    0    0    0    6    1    1]
#  [   0    1    3  998    0    8    0    0    2    0]
#  [   0    2    3    0  952    0    0    1    1    3]
#  [   0    2    0    3    0  867    0    0    0    2]
#  [   9    2    5    0    3   13  951    0    3    0]
#  [   0    6    9    4    2    0    0 1013    1    5]
#  [   0    0    3    1    1    1    1    0  961    0]
#  [   1    0    1    2   24    2    0    5    1  996]]

# %%
sample = next(iter(loaders['test']))
imgs, lbls = sample

# %%
actual_number = lbls[:10].numpy()
actual_number
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9])

# %%
test_output, last_layer = cnn(imgs[:10])
pred_y = torch.max(test_output, 1)[1].data.numpy().squeeze()
print(f'Prediction number: {pred_y}')
print(f'Actual number: {actual_number}')
# Out:
# Prediction number: [7 2 1 0 4 1 4 9 5 9]
# Actual number: [7 2 1 0 4 1 4 9 5 9]
